# %% [markdown]
# <a href="https://colab.research.google.com/github/ColinKim11/New-Repository/blob/main/Kim_Yong_the_A_I_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install discord.py
# !pip install nest_asyncio
# !pip install -U python-dotenv
# !pip install openai

# import datetime as dt
import asyncio, nest_asyncio
import discord
import random
import openai
import math


from discord.ext import commands
# from discord.utils import get
from dotenv import load_dotenv
from PIL import Image, ImageDraw, ImageFont


load_dotenv()

nest_asyncio.apply()

token = "MTAxMTUxODc4OTEwOTY4MjIzNg.GRSx7v.XtDhJh_5twW2etNvuFaZK-l4poRClHQJ_SOQcg"
openai.api_key = "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"


intents = discord.Intents.all()

bot = commands.Bot(command_prefix="~", intents=intents)

@bot.event
async def on_ready():
    print("김용봇 시작")
    print(bot.user.id)
    # await bot.change_presence(status=discord.Status.online)
    
    await bot.change_presence(status=discord.Status.dnd, activity=discord.Game(name="야근"))#Rainbow Six Siege | command prefix = ~ | 여자친구를 사랑 | 다시 시작 | 남들 모르게 연애 | 누군가를 사랑 | 업데이트 | (｢`･ω･)｢ | 乁( ˙ ω˙乁) | ♪╭(°ㅂ°)╯♪ ╰(•ω•)╮| 〜(^∇^〜） |
    

        
# 메시지====================================================================================================================
@bot.event
async def on_message(message):

    if message.author.bot:
        await bot.process_commands(message)
        return None 
    
    for i in ['dick', 'pussy', 'balls', 'bitch', 'ass', 'nut', 'nuts', 'onlyfans', 'fucking', 'asshole', 'cuck']: # 금지어
        if i in message.content:
            muted = discord.utils.get(message.channel.guild.roles, name='Muted')
            man = message.author
            manager_chat = bot.get_channel(921733030719139890)
            role = man.roles
            await message.channel.purge(limit=1)
            await man.edit(roles=[])
            await man.add_roles(muted)
            await man.send(f"금지어 <{i}> 사용으로 5분간 채팅을 금지하였습니다. \n단어 사용에 주의하여주세요.")
            await manager_chat.send(f'<{man}>님이 금지어 <{i}>를 사용하셨습니다.')
            await asyncio.sleep(300)
            await man.remove_roles(muted)
            await man.edit(roles=role)
            await message.channel.send(f'{man.mention} 채팅 금지 풀렸습니다.\n바르고 고운말을 사용합시다.')
    
    if message.content == '용하':
        reply = ['^ㅗ^', 't^^t', '안녕하세요~!', '김용 하이라는 뜻~', '용하~', '안용하살법 받아치기~!','😘','😒','🙄','😤','🤬']
        await message.channel.send(random.choice(reply))
        
    if '용님' in message.content and message.content.endswith('?') is True:
        answer_list = ['안돼요', '^^;', '으악', '그만해', '헤응...❤️', '그러던가', '아오', ':/', '난 감당 못 해...','나가','NAGA',';;;;','흥','에휴','그러다 혼나요','어라리','답없음','N\nO','ㅅㄱ','껄껄껄','^~^','\n\n#        #        #           ####           #    \n##     #      #  #      #         #        # #   \n# #    #     #   #      #                   #    #  \n#  #   #   #        #   #  ####   #        #\n#   #  #   #####  #          #    #####\n#    # #   #        #   #         #    #         # \n#        #   #        #    ####      #         # ']
        await message.channel.send(random.choice(answer_list))
        
    if '용님' in message.content and '잘생겼어요' in message.content:
        await message.channel.send('훗~ 내가 좀 잘생겼지 ㅎㅎ',file=discord.File('잘생긴김용.png'))
        
    if '오빠' in message.content and '사랑해요' in message.content:
        await message.channel.send('흥...!! 착각하지마..!!')
        await message.channel.send('나는 매니저라서 모두에게 친절할 뿐이야!')
        await message.channel.send('따... 딱히 너를 좋아하는건 아니니까!')
        await message.channel.send('\n\n\n(좋아해... 나도...)')
        
    """if '구라' in message.content:
        await message.channel.send('가우르 구라 귀여워~~',file=discord.File('gura.png'))
        
    if '아이돌' in message.content:
        await message.channel.send('아이돌은 고세구가 최고지 킹아~',file=discord.File('고세구.jpg'))"""
        
    for i in ['못생겼어요','BABO', '바보', '바부', '멍청이', '멍충이', '멍총이', '몽총이','qkqh','용바용보','멍충멍충']:
        if i in message.content:
            if i == '용바용보':
                await message.channel.send('닥쳐')
            elif '용님' in message.content:
                answer_list = ['으악','그만해','아오','헤응...❤️','나가','NAGA',';;;;','흥','에휴','그러다 혼나요','넌 나가라','#        #        #           ####           #    \n##     #      #  #      #         #        # #   \n# #    #     #   #      #                   #    #  \n#  #   #   #        #   #  ####   #        #\n#   #  #   #####  #          #    #####\n#    # #   #        #   #         #    #         # \n#        #   #        #    ####      #         # ']
                await message.channel.send(random.choice(answer_list))
            elif '넴무' in message.content:
                answer_list = ['ㄹㅇㅋㅋ','맞긴해','ㅋㅋ']
                await message.channel.send(random.choice(answer_list))
            else:
                pass
            
            
    await bot.process_commands(message)
# 넴비 희망자====================================================================================================================

"""    count = 0        
    if message.content == '!참가희망':
        channel = bot.get_channel(1029825451989946398)
        count = count + 1
        new_name = f'참가-희망자-{count}명'
        await channel.edit(name=new_name)
        
    await bot.process_commands(message)  """
    
# 수정함====================================================================================================================

@bot.event
async def on_message_edit(before, after):
    for i in ['dick', 'pussy', 'balls', 'bitch', 'fuck', 'ass', 'nut', 'nuts', 'onlyfans', 'fucking', 'asshole']: # 금지어
        if i in after.content:
            muted = discord.utils.get(after.channel.guild.roles, name='Muted')
            man = after.author
            manager_chat = bot.get_channel(921733030719139890)
            role = man.roles
            await after.channel.purge(limit=1)
            await man.edit(roles=[])
            await man.add_roles(muted)
            await man.send(f"금지어 <{i}> 사용으로 5분간 채팅을 금지하였습니다. \n단어 사용에 주의하여주세요.")
            await manager_chat.send(f'<{man}>님이 금지어 <{i}>를 사용하셨습니다.')
            await asyncio.sleep(300)
            await man.remove_roles(muted)
            await man.edit(roles=role)
            await after.channel.send(f'{man.mention} 채팅 금지 풀렸습니다.\n바르고 고운말을 사용합시다.')
                
    if '용님' in after.content and after.content.endswith('?') is True:
        answer_list = ['안돼요', '^^;', '으악', '그만해', '헤응...❤️', '그러던가', '아오', ':/', '난 감당 못 해...','나가','NAGA',';;;;','흥','에휴','그러다 혼나요','어라리','답없음','N\nO','ㅅㄱ','껄껄껄','^~^']
        await after.channel.send(random.choice(answer_list))
        
# 리액션====================================================================================================================
@bot.event
async def on_raw_reaction_add(payload):
    print("raw reaction added")
    channel = bot.get_channel(payload.channel_id)
    message_id = payload.message_id
    message = await channel.fetch_message(message_id)
    # await channel.send(str(payload.emoji))
    
    hk = discord.utils.get(bot.emojis, name='handsome_kimyong')

    if payload.emoji == hk:
        await channel.send(hk)
    if str(payload.emoji) == '🪄':
        await message.delete()
    if str(payload.emoji) == '🤐':
        await message.delete()
        muted = discord.utils.get(message.guild.roles, name='Muted')
        man = message.author
        role = man.roles
        await man.edit(roles=[])
        await man.add_roles(muted)
        await asyncio.sleep(300)
        await man.remove_roles(muted)
        await man.edit(roles=role)
    if str(payload.emoji) == '✉️':
        await message.delete()
        await message.author.send('단어가 부적절하다고 판단되어 DM 보냈습니다. 단어 사용에 주의하여주세요.')
    
# 커맨드====================================================================================================================
@bot.command(name="하이")
async def hello(ctx):
    reply = ['^ㅗ^', 't^^t', '안녕하세요~!', '용하~', '안용하살법 받아치기~!','😘','😒','🙄','😤','🤬']
    await ctx.send(random.choice(reply))
    
@bot.command(aliases=['명령어','김용'])
async def command(ctx):
    title = '안녕하세요! 김용봇입니다!'
    description = '넴무 디스코드 채널에서 사랑스러움을 담당하는 봇 김용봇입니다.\n사용 가능한 명령어들은 아래에서 보실 수 있어요.\n\n감사합니다!'
    embed = discord.Embed(title = title, description = description, color=0x8aa3e7)
    embed.add_field(name='명령어 보기',value='~명령어', inline=True)
    embed.add_field(name='김용과 인사하기',value='~하이', inline=True)
    embed.add_field(name='나가기',value='~나가', inline=True)
    embed.add_field(name='진짜 나가기',value='~진짜나가', inline=True)
    embed.add_field(name='용님 상태 확인',value='~오빠자?', inline=True)
    embed.add_field(name='헛짓거리 방 생성',value='~헛짓거리', inline=True)
    embed.add_field(name='팀원 찾는 방 생성',value='~구인구직', inline=True)
    embed.add_field(name='넴무가 또 술을 마실 때',value='~그거해봐그거1', inline=True)
    embed.add_field(name='넴무가 또 마라탕 먹을 때',value='~그거해봐그거2', inline=True)
    embed.add_field(name='별명 바꾸기',value='~change_nickname', inline=True)
    embed.add_field(name='용지피티한테 물어보기',value='~gpt', inline=True)
    embed.add_field(name='넴무티콘 만들기',value='~넴무티콘', inline=True)
    
    await ctx.send(embed=embed)
    
@bot.command(aliases=['나가','naga'])
async def NAGA(ctx):
    await ctx.send('넌 나가라',file=discord.File('김용 나가.png'))
    muted = discord.utils.get(ctx.guild.roles, name='Muted')
    man = ctx.author
    role = man.roles
    await man.edit(roles=[])
    await man.add_roles(muted)
    await asyncio.sleep(10)
    await man.remove_roles(muted)
    await man.edit(roles=role)
    
@bot.command(aliases=['진짜나가'])
async def KICK(ctx, reason=None):
    await ctx.send('넌 진짜 나가라',file=discord.File('김용 나가.png'))
    await ctx.author.send("https://discord.gg/zSUEDPn7")
    await ctx.author.kick(reason=reason)
    await ctx.send(f'{ctx.author.mention} 진짜 나감')
    
@bot.command(name='오빠자?')
async def test(ctx):
    print('Kim Yong the A.I. 작동 중')
    await ctx.send('오빠 안잔다')
    def check(reaction, user):
        return user == ctx.author and str(reaction.emoji) == '✅'
    try:
        reaction, user = await bot.wait_for('reaction_add', timeout=6.0, check=check)
    except asyncio.TimeoutError:
        await ctx.send('😒')
    else:
        await ctx.send('😋')
        # await ctx.channel.purge(limit=1)   
    
@bot.command(name="헛짓거리")
async def hutjit(ctx):
    if ctx.author.nick is None:
        channel_name = '🤪｜' + ctx.author.name + '의 헛짓거리'
    else:
        channel_name = '🤪｜' + ctx.author.nick + '의 헛짓거리'
    voice_category = discord.utils.get(ctx.guild.categories, name = '-----------(비방송용)-----------')
    await ctx.guild.create_voice_channel(name = channel_name, category = voice_category)
    
@bot.command(name="구인구직")
async def team(ctx):
    if ctx.author.nick is None:
        channel_name = '💪｜' + ctx.author.name + '의 팀원 찾는 방'
    else:
        channel_name = '💪｜' + ctx.author.nick + '의 팀원 찾는 방'
    voice_category = discord.utils.get(ctx.guild.categories, name = '-----------(비방송용)-----------')
    await ctx.guild.create_voice_channel(name = channel_name, category = voice_category)
   

@bot.command(name="그거해봐그거1")
async def that1(ctx):
    await ctx.send(file=discord.File('that 1.png'))
    
@bot.command(name="그거해봐그거2")
async def that2(ctx):
    await ctx.send(file=discord.File('that 2.png'))
    
@bot.command()
async def change_nickname(ctx, member, nick):
    if '+' in member:
        member = member.replace('+', ' ')
    if '+' in nick:
        nick = nick.replace('+', ' ')
    Member = discord.utils.get(ctx.guild.members, name=member) 
    if Member is None:
        await ctx.send(f'{member}의 이름이 잘못되었는지 확인해주세요!!!')
    else:
        try:
            await Member.edit(nick=nick)
            await ctx.send(f'<{Member.mention}>의 별명이 <{nick}>으로 변경되었습니다.')
        except:
            await ctx.send('넴무님, 김용님, 루아님의 별명은 바꿀 수 없어욧!!!')
        
@bot.command(name='gpt')
async def gpt(ctx, *, prompt: str):
    personality = ['Aggressive, hypocritical, and disrespectful', 'Kind, pure and timid', 'Weird nerd', 'Perverted incel', 'Pessimistic cynicist','Petty, behind-the-scenes, and annoying','Very stubborn and full of competitive desire','Depressed and unmotivated','Very quick-tempered and hot-tempered','Just a little stupid, stupid, stupid']
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": f"You are a man named Kim Yong the A.I.. Speak in a {random.choice(personality)} manner"},
            {"role": "user", "content": prompt},
        ]
    )

    await ctx.send(response['choices'][0]['message']['content'])
    
@bot.command(name='넴무티콘')
async def icon(ctx, *, text: str):
    length = len(text)
    if length <= 7:
        await ctx.channel.purge(limit=1)
        img = Image.open("paper_nemmu.png")
        size = 100 - int(math.sqrt(length)*20)

        font = ImageFont.truetype("tvN.ttf", size)
        fill = (0,0,0)

        x = 200-math.sqrt(length)*35
        y = 230+math.sqrt(length)*8

        xy = (x,y)

        tim = Image.new('RGBA', (430,430), (0,0,0,0))
        dr = ImageDraw.Draw(tim)
        dr.text(xy=xy, text=text, font=font, fill=fill)
        tim = tim.rotate(13,  expand=1)

        img.paste(tim, (0,0), tim)
        img.save("image.png")
        
        await ctx.send(file=discord.File('image.png'))
        
    else:
        await ctx.send("문자열이 너무 길어유 ㅜㅜ")
    
    

        
bot.run(token)
